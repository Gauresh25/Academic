# %%
import warnings
warnings.simplefilter(action = "ignore",category = FutureWarning)
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as st
# %matplotlib inline

sns.set(style="whitegrid")
data = "Absenteeism_at_work.csv"

df = pd.read_csv(data, sep=";")

print(df.shape) #rows and cols
# Out:
# (740, 21)

# %%
print(df.head) #1st 5 rows
# Out:
# <bound method NDFrame.head of      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
# ...

# %%
print(df.info())#This method prints information about a dataFrame including the index, column names and data types, non-null values and memory usage.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               740 non-null    int64
#  1   Reason for absence               740 non-null    int64
#  2   Month of absence                 740 non-null    int64
#  3   Day of the week                  740 non-null    int64
#  4   Seasons                          740 non-null    int64
#  5   Transportation expense           740 non-null    int64
#  6   Distance from Residence to Work  740 non-null    int64
#  7   Service time                     740 non-null    int64
#  8   Age                              740 non-null    int64
#  9   Work load Average/day            740 non-null    float64
#  10  Hit target                       740 non-null    int64
#  11  Disciplinary failure             740 non-null    int64
# ...

# %%
print(df.describe())
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  740.000000          740.000000        740.000000       740.000000
# mean    18.017568           19.216216          6.324324         3.914865
# std     11.021247            8.433406          3.436287         1.421675
# min      1.000000            0.000000          0.000000         2.000000
# 25%      9.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.000000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  740.000000              740.000000                       740.000000
# mean     2.544595              221.329730                        29.631081
# std      1.111831               66.952223                        14.836788
# ...

# %%
df.isnull().sum()
#pd.isna(df['col_name']) for column
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %% [markdown]
# Univariate analysis

# %%
print(df['Absenteeism time in hours'].describe())
# Out:
# count    740.000000
# mean       6.924324
# std       13.330998
# min        0.000000
# 25%        2.000000
# 50%        3.000000
# 75%        8.000000
# max      120.000000
# Name: Absenteeism time in hours, dtype: float64

# %%
plt.figure()
sns.distplot(df["Absenteeism time in hours"])
#plt.title("Skewness check")
plt.show()
# Out:
# C:\Users\Gauresh\AppData\Local\Temp\ipykernel_27276\3203719495.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Absenteeism time in hours"])

# %%
df['Social drinker'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Social drinker'>

# %%
plt.figure()
sns.heatmap(correlation, square=True, annot=True, fmt='.2f', linecolor='white')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 2
#       1 plt.figure()
# ----> 2 sns.heatmap(correlation, square=True, annot=True, fmt='.2f', linecolor='white')
#       3 plt.show()
#
# NameError: name 'correlation' is not defined

# %%
num_var = ['Transportation expense', 'Distance from Residence to Work']
sns.pairplot(df[num_var])
plt.show()

# %%
sns.lmplot(x='Absenteeism time in hours', y='Height', data=df)
plt.show()

# %%
plt.boxplot(df['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2db44114ce0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2db441152b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2db42c088f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2db44115640>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2db44115940>],
#  'means': []}
